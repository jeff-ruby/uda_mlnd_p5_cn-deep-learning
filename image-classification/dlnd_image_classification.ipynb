# %% [markdown]
# # 图像分类
#
# 在此项目中，你将对 [CIFAR-10 数据集](https://www.cs.toronto.edu/~kriz/cifar.html) 中的图片进行分类。该数据集包含飞机、猫狗和其他物体。你需要预处理这些图片，然后用所有样本训练一个卷积神经网络。图片需要标准化（normalized），标签需要采用 one-hot 编码。你需要应用所学的知识构建卷积的、最大池化（max pooling）、丢弃（dropout）和完全连接（fully connected）的层。最后，你需要在样本图片上看到神经网络的预测结果。
#
#
# ## 获取数据
#
# 请运行以下单元，以下载 [CIFAR-10 数据集（Python版）](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz)。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [00:26, 6.45MB/s]
# All files found!

# %% [markdown]
# ## 探索数据
#
# 该数据集分成了几部分／批次（batches），以免你的机器在计算时内存不足。CIFAR-10 数据集包含 5 个部分，名称分别为 `data_batch_1`、`data_batch_2`，以此类推。每个部分都包含以下某个类别的标签和图片：
#
# * 飞机
# * 汽车
# * 鸟类
# * 猫
# * 鹿
# * 狗
# * 青蛙
# * 马
# * 船只
# * 卡车
#
# 了解数据集也是对数据进行预测的必经步骤。你可以通过更改 `batch_id` 和 `sample_id` 探索下面的代码单元。`batch_id` 是数据集一个部分的 ID（1 到 5）。`sample_id` 是该部分中图片和标签对（label pair）的 ID。
#
# 问问你自己：“可能的标签有哪些？”、“图片数据的值范围是多少？”、“标签是按顺序排列，还是随机排列的？”。思考类似的问题，有助于你预处理数据，并使预测结果更准确。

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# /home/ubuntu/anaconda/lib/python3.6/site-packages/matplotlib/font_manager.py:281: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## 实现预处理函数
#
# ### 标准化
#
# 在下面的单元中，实现 `normalize` 函数，传入图片数据 `x`，并返回标准化 Numpy 数组。值应该在 0 到 1 的范围内（含 0 和 1）。返回对象应该和 `x` 的形状一样。

# %%
import numpy as np
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    x = np.array(x)
    x = (x - x.min())/(x.max() - x.min())

    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot 编码
#
# 和之前的代码单元一样，你将为预处理实现一个函数。这次，你将实现 `one_hot_encode` 函数。输入，也就是 `x`，是一个标签列表。实现该函数，以返回为 one_hot 编码的 Numpy 数组的标签列表。标签的可能值为 0 到 9。每次调用 `one_hot_encode` 时，对于每个值，one_hot 编码函数应该返回相同的编码。确保将编码映射保存到该函数外面。
#
# 提示：不要重复发明轮子。

# %%
from sklearn.preprocessing import LabelBinarizer
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    lb = LabelBinarizer().fit(range(10))
    x = lb.transform(x)

    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### 随机化数据
#
# 之前探索数据时，你已经了解到，样本的顺序是随机的。再随机化一次也不会有什么关系，但是对于这个数据集没有必要。

# %% [markdown]
# ## 预处理所有数据并保存
#
# 运行下方的代码单元，将预处理所有 CIFAR-10 数据，并保存到文件中。下面的代码还使用了 10% 的训练数据，用来验证。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # 检查点
#
# 这是你的第一个检查点。如果你什么时候决定再回到该记事本，或需要重新启动该记事本，你可以从这里开始。预处理的数据已保存到本地。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## 构建网络
#
# 对于该神经网络，你需要将每层都构建为一个函数。你看到的大部分代码都位于函数外面。要更全面地测试你的代码，我们需要你将每层放入一个函数中。这样使我们能够提供更好的反馈，并使用我们的统一测试检测简单的错误，然后再提交项目。
#
# >**注意**：如果你觉得每周很难抽出足够的时间学习这门课程，我们为此项目提供了一个小捷径。对于接下来的几个问题，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 程序包中的类来构建每个层级，但是“卷积和最大池化层级”部分的层级除外。TF Layers 和 Keras 及 TFLearn 层级类似，因此很容易学会。
#
# >但是，如果你想充分利用这门课程，请尝试自己解决所有问题，不使用 TF Layers 程序包中的任何类。你依然可以使用其他程序包中的类，这些类和你在 TF Layers 中的类名称是一样的！例如，你可以使用 TF Neural Network 版本的 `conv2d` 类 [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d)，而不是 TF Layers 版本的 `conv2d` 类 [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d)。
#
# 我们开始吧！
#
#
# ### 输入
#
# 神经网络需要读取图片数据、one-hot 编码标签和丢弃保留概率（dropout keep probability）。请实现以下函数：
#
# * 实现 `neural_net_image_input`
#  * 返回 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * 使用 `image_shape` 设置形状，部分大小设为 `None`
#  * 使用 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) 中的 TensorFlow `name` 参数对 TensorFlow 占位符 "x" 命名
# * 实现 `neural_net_label_input`
#  * 返回 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * 使用 `n_classes` 设置形状，部分大小设为 `None`
#  * 使用 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) 中的 TensorFlow `name` 参数对 TensorFlow 占位符 "y" 命名
# * 实现 `neural_net_keep_prob_input`
#  * 返回 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)，用于丢弃保留概率
#  * 使用 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) 中的 TensorFlow `name` 参数对 TensorFlow 占位符 "keep_prob" 命名
#
# 这些名称将在项目结束时，用于加载保存的模型。
#
# 注意：TensorFlow 中的 `None` 表示形状可以是动态大小。

# %%
import tensorflow as tf
import numpy as np

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    w, h, d = image_shape
    x = tf.placeholder(tf.float32, [None, w, h, d], name='x')
    return x


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    y = tf.placeholder(tf.float32, [None, n_classes], name='y')
    return y


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    return keep_prob


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### 卷积和最大池化层
#
# 卷积层级适合处理图片。对于此代码单元，你应该实现函数 `conv2d_maxpool` 以便应用卷积然后进行最大池化：
#
# * 使用 `conv_ksize`、`conv_num_outputs` 和 `x_tensor` 的形状创建权重（weight）和偏置（bias）。
# * 使用权重和 `conv_strides` 对 `x_tensor` 应用卷积。
#  * 建议使用我们建议的间距（padding），当然也可以使用任何其他间距。
# * 添加偏置
# * 向卷积中添加非线性激活（nonlinear activation）
# * 使用 `pool_ksize` 和 `pool_strides` 应用最大池化
#  * 建议使用我们建议的间距（padding），当然也可以使用任何其他间距。
#
# **注意**：对于**此层**，**请勿使用** [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers)，但是仍然可以使用 TensorFlow 的 [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) 包。对于所有**其他层**，你依然可以使用快捷方法。

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    wc = tf.Variable(tf.truncated_normal(\
                        shape = [conv_ksize[0], conv_ksize[1], int(x_tensor.shape[3]), conv_num_outputs], \
                        stddev = 0.05))
    bc = tf.Variable(tf.zeros(conv_num_outputs))

    x_tensor = tf.nn.conv2d(x_tensor, wc, strides=[1, conv_strides[0], conv_strides[1], 1], padding='SAME')
    x_tensor = tf.nn.bias_add(x_tensor, bc)
    x_tensor = tf.nn.relu(x_tensor)
    
    x_tensor = tf.nn.max_pool(x_tensor, \
                             ksize=[1, pool_ksize[0], pool_ksize[1], 1], \
                             strides=[1, pool_strides[0], pool_strides[1], 1], padding='SAME')
    
    return x_tensor 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### 扁平化层
#
# 实现 `flatten` 函数，将 `x_tensor` 的维度从四维张量（4-D tensor）变成二维张量。输出应该是形状（*部分大小（Batch Size）*，*扁平化图片大小（Flattened Image Size）*）。快捷方法：对于此层，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的类。如果你想要更大挑战，可以仅使用其他 TensorFlow 程序包。

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    '''
    x_tensor = tf.layers.flatten(x_tensor)
    '''
    x_tensor = tf.reshape(x_tensor, [-1, int(x_tensor.shape[1]*x_tensor.shape[2]*x_tensor.shape[3])])
    return x_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### 全连接层
#
# 实现 `fully_conn` 函数，以向 `x_tensor` 应用完全连接的层级，形状为（*部分大小（Batch Size）*，*num_outputs*）。快捷方法：对于此层，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的类。如果你想要更大挑战，可以仅使用其他 TensorFlow 程序包。

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    wf = tf.Variable(tf.truncated_normal(\
                        shape = [int(x_tensor.shape[1]), num_outputs], \
                        stddev = 0.05))
    bf = tf.Variable(tf.zeros(num_outputs))
        
    x_tensor = tf.add(tf.matmul(x_tensor, wf), bf)
    x_tensor = tf.nn.relu(x_tensor)
    
    return x_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### 输出层
#
# 实现 `output` 函数，向 x_tensor 应用完全连接的层级，形状为（*部分大小（Batch Size）*，*num_outputs*）。快捷方法：对于此层，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的类。如果你想要更大挑战，可以仅使用其他 TensorFlow 程序包。
#
# **注意**：该层级不应应用 Activation、softmax 或交叉熵（cross entropy）。

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    wf = tf.Variable(tf.truncated_normal(\
                        shape = [int(x_tensor.shape[1]), num_outputs], \
                        stddev = 0.05))
    bf = tf.Variable(tf.zeros(num_outputs))
    
    x_tensor = tf.add(tf.matmul(x_tensor, wf), bf)
    return x_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### 创建卷积模型
#
# 实现函数 `conv_net`， 创建卷积神经网络模型。该函数传入一批图片 `x`，并输出对数（logits）。使用你在上方创建的层创建此模型：
#
# * 应用 1、2 或 3 个卷积和最大池化层（Convolution and Max Pool layers）
# * 应用一个扁平层（Flatten Layer）
# * 应用 1、2 或 3 个完全连接层（Fully Connected Layers）
# * 应用一个输出层（Output Layer）
# * 返回输出
# * 使用 `keep_prob` 向模型中的一个或多个层应用 [TensorFlow 的 Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout)

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    # 32*32*3 => 32*32*32 => 16*16*32
    x = conv2d_maxpool(x, 64, (5, 5), (1, 1), (3, 3), (2, 2))
    print('shape of 1st ConvNet: ', x.shape)
    x = conv2d_maxpool(x, 64, (5, 5), (1, 1), (3, 3), (2, 2))
    print('shape of 2nd ConvNet: ', x.shape)

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    x = flatten(x)
    print('shape of flattern: ', x.shape)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    x = fully_conn(x, 256)
    x = tf.nn.dropout(x, keep_prob)
    x = fully_conn(x, 128)
    x = tf.nn.dropout(x, keep_prob)
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    x = output(x, 10)
    
    # TODO: return output
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# shape of 1st ConvNet:  (?, 16, 16, 64)
# shape of 2nd ConvNet:  (?, 8, 8, 64)
# shape of flattern:  (?, 4096)
# shape of 1st ConvNet:  (?, 16, 16, 64)
# shape of 2nd ConvNet:  (?, 8, 8, 64)
# shape of flattern:  (?, 4096)
# Neural Network Built!

# %% [markdown]
# ## 训练神经网络
#
# ### 单次优化
#
# 实现函数 `train_neural_network` 以进行单次优化（single optimization）。该优化应该使用 `optimizer` 优化 `session`，其中 `feed_dict` 具有以下参数：
#
# * `x` 表示图片输入
# * `y` 表示标签
# * `keep_prob` 表示丢弃的保留率
#
# 每个部分都会调用该函数，所以 `tf.global_variables_initializer()` 已经被调用。
#
# 注意：不需要返回任何内容。该函数只是用来优化神经网络。

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer, feed_dict = {
                x:feature_batch,
                y:label_batch,
                keep_prob:keep_probability})
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### 显示数据
#
# 实现函数 `print_stats` 以输出损失和验证准确率。使用全局变量 `valid_features` 和 `valid_labels` 计算验证准确率。使用保留率 `1.0` 计算损失和验证准确率（loss and validation accuracy）。

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    current_cost = session.run(
        cost,
        feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.})
    valid_accuracy = session.run(
        accuracy,
        feed_dict={x: valid_features, y: valid_labels, keep_prob: 1.})
    print('Cost: {:<10.6f} Valid Accuracy: {:.6f}'.format(
        current_cost,
        valid_accuracy))

# %% [markdown]
# ### 超参数
#
# 调试以下超参数：
# * 设置 `epochs` 表示神经网络停止学习或开始过拟合的迭代次数
# * 设置 `batch_size`，表示机器内存允许的部分最大体积。大部分人设为以下常见内存大小：
#
#  * 64
#  * 128
#  * 256
#  * ...
# * 设置 `keep_probability` 表示使用丢弃时保留节点的概率

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 256
keep_probability = 0.5

# %% [markdown]
# ### 在单个 CIFAR-10 部分上训练
#
# 我们先用单个部分，而不是用所有的 CIFAR-10 批次训练神经网络。这样可以节省时间，并对模型进行迭代，以提高准确率。最终验证准确率达到 50% 或以上之后，在下一部分对所有数据运行模型。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end=' ')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:   Cost: 2.017389   Valid Accuracy: 0.353400
# Epoch  2, CIFAR-10 Batch 1:   Cost: 1.771535   Valid Accuracy: 0.411000
# Epoch  3, CIFAR-10 Batch 1:   Cost: 1.613968   Valid Accuracy: 0.447600
# Epoch  4, CIFAR-10 Batch 1:   Cost: 1.415921   Valid Accuracy: 0.482800
# Epoch  5, CIFAR-10 Batch 1:   Cost: 1.261514   Valid Accuracy: 0.505400
# Epoch  6, CIFAR-10 Batch 1:   Cost: 1.064492   Valid Accuracy: 0.526600
# Epoch  7, CIFAR-10 Batch 1:   Cost: 0.969087   Valid Accuracy: 0.525400
# Epoch  8, CIFAR-10 Batch 1:   Cost: 0.821531   Valid Accuracy: 0.535200
# Epoch  9, CIFAR-10 Batch 1:   Cost: 0.739571   Valid Accuracy: 0.545400
# Epoch 10, CIFAR-10 Batch 1:   Cost: 0.571566   Valid Accuracy: 0.571800
# Epoch 11, CIFAR-10 Batch 1:   Cost: 0.509416   Valid Accuracy: 0.579000
# Epoch 12, CIFAR-10 Batch 1:   Cost: 0.410346   Valid Accuracy: 0.566200
# Epoch 13, CIFAR-10 Batch 1:   Cost: 0.414209   Valid Accuracy: 0.564400
# Epoch 14, CIFAR-10 Batch 1:   Cost: 0.308622   Valid Accuracy: 0.593000
# Epoch 15, CIFAR-10 Batch 1:   Cost: 0.283251   Valid Accuracy: 0.606000
# Epoch 16, CIFAR-10 Batch 1:   Cost: 0.178591   Valid Accuracy: 0.616000
# Epoch 17, CIFAR-10 Batch 1:   Cost: 0.143790   Valid Accuracy: 0.620400
# Epoch 18, CIFAR-10 Batch 1:   Cost: 0.125792   Valid Accuracy: 0.620600
# Epoch 19, CIFAR-10 Batch 1:   Cost: 0.112446   Valid Accuracy: 0.609400
# Epoch 20, CIFAR-10 Batch 1:   Cost: 0.094794   Valid Accuracy: 0.608200
# Epoch 21, CIFAR-10 Batch 1:   Cost: 0.090033   Valid Accuracy: 0.612800
# Epoch 22, CIFAR-10 Batch 1:   Cost: 0.082730   Valid Accuracy: 0.579600
# Epoch 23, CIFAR-10 Batch 1:   Cost: 0.083788   Valid Accuracy: 0.569200
# Epoch 24, CIFAR-10 Batch 1:   Cost: 0.073775   Valid Accuracy: 0.583400
# Epoch 25, CIFAR-10 Batch 1:   Cost: 0.036334   Valid Accuracy: 0.605000
# Epoch 26, CIFAR-10 Batch 1:   Cost: 0.028610   Valid Accuracy: 0.606200
# Epoch 27, CIFAR-10 Batch 1:   Cost: 0.027597   Valid Accuracy: 0.613000
# Epoch 28, CIFAR-10 Batch 1:   Cost: 0.024983   Valid Accuracy: 0.611000
# Epoch 29, CIFAR-10 Batch 1:   Cost: 0.027889   Valid Accuracy: 0.616600
# Epoch 30, CIFAR-10 Batch 1:   Cost: 0.036671   Valid Accuracy: 0.603000

# %% [markdown]
# ### 完全训练模型
#
# 现在，单个 CIFAR-10 部分的准确率已经不错了，试试所有五个部分吧。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Cost: 2.161284   Valid Accuracy: 0.274800
# Epoch  1, CIFAR-10 Batch 2:  Cost: 1.809873   Valid Accuracy: 0.351600
# Epoch  1, CIFAR-10 Batch 3:  Cost: 1.477850   Valid Accuracy: 0.400200
# Epoch  1, CIFAR-10 Batch 4:  Cost: 1.560648   Valid Accuracy: 0.425200
# Epoch  1, CIFAR-10 Batch 5:  Cost: 1.503248   Valid Accuracy: 0.438800
# Epoch  2, CIFAR-10 Batch 1:  Cost: 1.528180   Valid Accuracy: 0.484800
# Epoch  2, CIFAR-10 Batch 2:  Cost: 1.424484   Valid Accuracy: 0.475400
# Epoch  2, CIFAR-10 Batch 3:  Cost: 1.029078   Valid Accuracy: 0.507600
# Epoch  2, CIFAR-10 Batch 4:  Cost: 1.274284   Valid Accuracy: 0.537200
# Epoch  2, CIFAR-10 Batch 5:  Cost: 1.194736   Valid Accuracy: 0.549400
# Epoch  3, CIFAR-10 Batch 1:  Cost: 1.216127   Valid Accuracy: 0.542600
# Epoch  3, CIFAR-10 Batch 2:  Cost: 1.019800   Valid Accuracy: 0.567000
# Epoch  3, CIFAR-10 Batch 3:  Cost: 0.824731   Valid Accuracy: 0.550200
# Epoch  3, CIFAR-10 Batch 4:  Cost: 1.106211   Valid Accuracy: 0.594800
# Epoch  3, CIFAR-10 Batch 5:  Cost: 1.044830   Valid Accuracy: 0.561400
# Epoch  4, CIFAR-10 Batch 1:  Cost: 0.962052   Valid Accuracy: 0.613400
# Epoch  4, CIFAR-10 Batch 2:  Cost: 0.833079   Valid Accuracy: 0.612200
# Epoch  4, CIFAR-10 Batch 3:  Cost: 0.659937   Valid Accuracy: 0.619000
# Epoch  4, CIFAR-10 Batch 4:  Cost: 0.902268   Valid Accuracy: 0.624600
# Epoch  4, CIFAR-10 Batch 5:  Cost: 0.805828   Valid Accuracy: 0.614800
# Epoch  5, CIFAR-10 Batch 1:  Cost: 0.763058   Valid Accuracy: 0.649000
# Epoch  5, CIFAR-10 Batch 2:  Cost: 0.643057   Valid Accuracy: 0.634600
# Epoch  5, CIFAR-10 Batch 3:  Cost: 0.522891   Valid Accuracy: 0.648400
# Epoch  5, CIFAR-10 Batch 4:  Cost: 0.681623   Valid Accuracy: 0.661000
# Epoch  5, CIFAR-10 Batch 5:  Cost: 0.675182   Valid Accuracy: 0.648400
# Epoch  6, CIFAR-10 Batch 1:  Cost: 0.658603   Valid Accuracy: 0.642400
# Epoch  6, CIFAR-10 Batch 2:  Cost: 0.571496   Valid Accuracy: 0.648400
# Epoch  6, CIFAR-10 Batch 3:  Cost: 0.425536   Valid Accuracy: 0.659400
# Epoch  6, CIFAR-10 Batch 4:  Cost: 0.582562   Valid Accuracy: 0.667000
# Epoch  6, CIFAR-10 Batch 5:  Cost: 0.481982   Valid Accuracy: 0.655000
# Epoch  7, CIFAR-10 Batch 1:  Cost: 0.640681   Valid Accuracy: 0.672400
# Epoch  7, CIFAR-10 Batch 2:  Cost: 0.448261   Valid Accuracy: 0.685600
# Epoch  7, CIFAR-10 Batch 3:  Cost: 0.383525   Valid Accuracy: 0.664000
# Epoch  7, CIFAR-10 Batch 4:  Cost: 0.489890   Valid Accuracy: 0.680400
# Epoch  7, CIFAR-10 Batch 5:  Cost: 0.438322   Valid Accuracy: 0.683600
# Epoch  8, CIFAR-10 Batch 1:  Cost: 0.511172   Valid Accuracy: 0.681400
# Epoch  8, CIFAR-10 Batch 2:  Cost: 0.399480   Valid Accuracy: 0.695400
# Epoch  8, CIFAR-10 Batch 3:  Cost: 0.283550   Valid Accuracy: 0.687800
# Epoch  8, CIFAR-10 Batch 4:  Cost: 0.456165   Valid Accuracy: 0.697600
# Epoch  8, CIFAR-10 Batch 5:  Cost: 0.326088   Valid Accuracy: 0.682600
# Epoch  9, CIFAR-10 Batch 1:  Cost: 0.420717   Valid Accuracy: 0.710400
# Epoch  9, CIFAR-10 Batch 2:  Cost: 0.307242   Valid Accuracy: 0.706600
# Epoch  9, CIFAR-10 Batch 3:  Cost: 0.209840   Valid Accuracy: 0.697400
# Epoch  9, CIFAR-10 Batch 4:  Cost: 0.369843   Valid Accuracy: 0.709200
# Epoch  9, CIFAR-10 Batch 5:  Cost: 0.289581   Valid Accuracy: 0.711800
# Epoch 10, CIFAR-10 Batch 1:  Cost: 0.373538   Valid Accuracy: 0.702200
# Epoch 10, CIFAR-10 Batch 2:  Cost: 0.256180   Valid Accuracy: 0.708000
# Epoch 10, CIFAR-10 Batch 3:  Cost: 0.216769   Valid Accuracy: 0.700000
# Epoch 10, CIFAR-10 Batch 4:  Cost: 0.366350   Valid Accuracy: 0.706800
# Epoch 10, CIFAR-10 Batch 5:  Cost: 0.242399   Valid Accuracy: 0.715200
# Epoch 11, CIFAR-10 Batch 1:  Cost: 0.355186   Valid Accuracy: 0.699200
# Epoch 11, CIFAR-10 Batch 2:  Cost: 0.229990   Valid Accuracy: 0.706600
# Epoch 11, CIFAR-10 Batch 3:  Cost: 0.169491   Valid Accuracy: 0.711800
# Epoch 11, CIFAR-10 Batch 4:  Cost: 0.314929   Valid Accuracy: 0.701200
# Epoch 11, CIFAR-10 Batch 5:  Cost: 0.217968   Valid Accuracy: 0.711200
# Epoch 12, CIFAR-10 Batch 1:  Cost: 0.335509   Valid Accuracy: 0.708200
# Epoch 12, CIFAR-10 Batch 2:  Cost: 0.204871   Valid Accuracy: 0.723800
# Epoch 12, CIFAR-10 Batch 3:  Cost: 0.148782   Valid Accuracy: 0.715400
# Epoch 12, CIFAR-10 Batch 4:  Cost: 0.281913   Valid Accuracy: 0.708000
# Epoch 12, CIFAR-10 Batch 5:  Cost: 0.170175   Valid Accuracy: 0.717600
# Epoch 13, CIFAR-10 Batch 1:  Cost: 0.269375   Valid Accuracy: 0.713000
# Epoch 13, CIFAR-10 Batch 2:  Cost: 0.199655   Valid Accuracy: 0.724800
# Epoch 13, CIFAR-10 Batch 3:  Cost: 0.123687   Valid Accuracy: 0.711600
# Epoch 13, CIFAR-10 Batch 4:  Cost: 0.246223   Valid Accuracy: 0.718800
# Epoch 13, CIFAR-10 Batch 5:  Cost: 0.146631   Valid Accuracy: 0.730400
# Epoch 14, CIFAR-10 Batch 1:  Cost: 0.193116   Valid Accuracy: 0.729800
# Epoch 14, CIFAR-10 Batch 2:  Cost: 0.141219   Valid Accuracy: 0.735800
# Epoch 14, CIFAR-10 Batch 3:  Cost: 0.103824   Valid Accuracy: 0.726000
# Epoch 14, CIFAR-10 Batch 4:  Cost: 0.199515   Valid Accuracy: 0.736400
# Epoch 14, CIFAR-10 Batch 5:  Cost: 0.108360   Valid Accuracy: 0.721400
# Epoch 15, CIFAR-10 Batch 1:  Cost: 0.215709   Valid Accuracy: 0.728400
# Epoch 15, CIFAR-10 Batch 2:  Cost: 0.151909   Valid Accuracy: 0.735800
# Epoch 15, CIFAR-10 Batch 3:  Cost: 0.099881   Valid Accuracy: 0.733400
# Epoch 15, CIFAR-10 Batch 4:  Cost: 0.171451   Valid Accuracy: 0.734400
# Epoch 15, CIFAR-10 Batch 5:  Cost: 0.092609   Valid Accuracy: 0.733400
# Epoch 16, CIFAR-10 Batch 1:  Cost: 0.191673   Valid Accuracy: 0.740800
# Epoch 16, CIFAR-10 Batch 2:  Cost: 0.131586   Valid Accuracy: 0.721000
# Epoch 16, CIFAR-10 Batch 3:  Cost: 0.083542   Valid Accuracy: 0.729000
# Epoch 16, CIFAR-10 Batch 4:  Cost: 0.175521   Valid Accuracy: 0.727200
# Epoch 16, CIFAR-10 Batch 5:  Cost: 0.065024   Valid Accuracy: 0.731400
# Epoch 17, CIFAR-10 Batch 1:  Cost: 0.167762   Valid Accuracy: 0.727800
# Epoch 17, CIFAR-10 Batch 2:  Cost: 0.110021   Valid Accuracy: 0.731600
# Epoch 17, CIFAR-10 Batch 3:  Cost: 0.082898   Valid Accuracy: 0.720400
# Epoch 17, CIFAR-10 Batch 4:  Cost: 0.155811   Valid Accuracy: 0.731600
# Epoch 17, CIFAR-10 Batch 5:  Cost: 0.067549   Valid Accuracy: 0.728200
# Epoch 18, CIFAR-10 Batch 1:  Cost: 0.161453   Valid Accuracy: 0.722400
# Epoch 18, CIFAR-10 Batch 2:  Cost: 0.112875   Valid Accuracy: 0.737600
# Epoch 18, CIFAR-10 Batch 3:  Cost: 0.074793   Valid Accuracy: 0.732000
# Epoch 18, CIFAR-10 Batch 4:  Cost: 0.108208   Valid Accuracy: 0.737400
# Epoch 18, CIFAR-10 Batch 5:  Cost: 0.070670   Valid Accuracy: 0.727800
# Epoch 19, CIFAR-10 Batch 1:  Cost: 0.145359   Valid Accuracy: 0.730800
# Epoch 19, CIFAR-10 Batch 2:  Cost: 0.091158   Valid Accuracy: 0.725800
# Epoch 19, CIFAR-10 Batch 3:  Cost: 0.056989   Valid Accuracy: 0.739400
# Epoch 19, CIFAR-10 Batch 4:  Cost: 0.122515   Valid Accuracy: 0.725200
# Epoch 19, CIFAR-10 Batch 5:  Cost: 0.054408   Valid Accuracy: 0.718800
# Epoch 20, CIFAR-10 Batch 1:  Cost: 0.139831   Valid Accuracy: 0.738000
# Epoch 20, CIFAR-10 Batch 2:  Cost: 0.091288   Valid Accuracy: 0.733600
# Epoch 20, CIFAR-10 Batch 3:  Cost: 0.082205   Valid Accuracy: 0.732000
# Epoch 20, CIFAR-10 Batch 4:  Cost: 0.106303   Valid Accuracy: 0.725800
# Epoch 20, CIFAR-10 Batch 5:  Cost: 0.064333   Valid Accuracy: 0.714800
# Epoch 21, CIFAR-10 Batch 1:  Cost: 0.112626   Valid Accuracy: 0.728000
# Epoch 21, CIFAR-10 Batch 2:  Cost: 0.076400   Valid Accuracy: 0.734800
# Epoch 21, CIFAR-10 Batch 3:  Cost: 0.043789   Valid Accuracy: 0.734000
# Epoch 21, CIFAR-10 Batch 4:  Cost: 0.093613   Valid Accuracy: 0.725800
# Epoch 21, CIFAR-10 Batch 5:  Cost: 0.051329   Valid Accuracy: 0.698200
# Epoch 22, CIFAR-10 Batch 1:  Cost: 0.119742   Valid Accuracy: 0.741400
# Epoch 22, CIFAR-10 Batch 2:  Cost: 0.084825   Valid Accuracy: 0.732600
# Epoch 22, CIFAR-10 Batch 3:  Cost: 0.062072   Valid Accuracy: 0.739000
# Epoch 22, CIFAR-10 Batch 4:  Cost: 0.087912   Valid Accuracy: 0.730800
# Epoch 22, CIFAR-10 Batch 5:  Cost: 0.034421   Valid Accuracy: 0.729600
# Epoch 23, CIFAR-10 Batch 1:  Cost: 0.102071   Valid Accuracy: 0.740000
# Epoch 23, CIFAR-10 Batch 2:  Cost: 0.071342   Valid Accuracy: 0.730000
# Epoch 23, CIFAR-10 Batch 3:  Cost: 0.045736   Valid Accuracy: 0.737000
# Epoch 23, CIFAR-10 Batch 4:  Cost: 0.078148   Valid Accuracy: 0.732600
# Epoch 23, CIFAR-10 Batch 5:  Cost: 0.018629   Valid Accuracy: 0.730600
# Epoch 24, CIFAR-10 Batch 1:  Cost: 0.102070   Valid Accuracy: 0.732000
# Epoch 24, CIFAR-10 Batch 2:  Cost: 0.051725   Valid Accuracy: 0.736200
# Epoch 24, CIFAR-10 Batch 3:  Cost: 0.041336   Valid Accuracy: 0.728200
# Epoch 24, CIFAR-10 Batch 4:  Cost: 0.079314   Valid Accuracy: 0.736400
# Epoch 24, CIFAR-10 Batch 5:  Cost: 0.020706   Valid Accuracy: 0.721800
# Epoch 25, CIFAR-10 Batch 1:  Cost: 0.108282   Valid Accuracy: 0.747200
# Epoch 25, CIFAR-10 Batch 2:  Cost: 0.047444   Valid Accuracy: 0.738000
# Epoch 25, CIFAR-10 Batch 3:  Cost: 0.056066   Valid Accuracy: 0.726200
# Epoch 25, CIFAR-10 Batch 4:  Cost: 0.087920   Valid Accuracy: 0.723600
# Epoch 25, CIFAR-10 Batch 5:  Cost: 0.019515   Valid Accuracy: 0.740400
# Epoch 26, CIFAR-10 Batch 1:  Cost: 0.065560   Valid Accuracy: 0.738600
# Epoch 26, CIFAR-10 Batch 2:  Cost: 0.049151   Valid Accuracy: 0.734400
# Epoch 26, CIFAR-10 Batch 3:  Cost: 0.033260   Valid Accuracy: 0.731200
# Epoch 26, CIFAR-10 Batch 4:  Cost: 0.058507   Valid Accuracy: 0.739000
# Epoch 26, CIFAR-10 Batch 5:  Cost: 0.018913   Valid Accuracy: 0.736200
# Epoch 27, CIFAR-10 Batch 1:  Cost: 0.085580   Valid Accuracy: 0.735200
# Epoch 27, CIFAR-10 Batch 2:  Cost: 0.046773   Valid Accuracy: 0.737600
# Epoch 27, CIFAR-10 Batch 3:  Cost: 0.023905   Valid Accuracy: 0.736600
# Epoch 27, CIFAR-10 Batch 4:  Cost: 0.079876   Valid Accuracy: 0.740600
# Epoch 27, CIFAR-10 Batch 5:  Cost: 0.016545   Valid Accuracy: 0.731400
# Epoch 28, CIFAR-10 Batch 1:  Cost: 0.066681   Valid Accuracy: 0.727600
# Epoch 28, CIFAR-10 Batch 2:  Cost: 0.068781   Valid Accuracy: 0.724600
# Epoch 28, CIFAR-10 Batch 3:  Cost: 0.031843   Valid Accuracy: 0.730600
# Epoch 28, CIFAR-10 Batch 4:  Cost: 0.062578   Valid Accuracy: 0.739600
# Epoch 28, CIFAR-10 Batch 5:  Cost: 0.021036   Valid Accuracy: 0.737000
# Epoch 29, CIFAR-10 Batch 1:  Cost: 0.060556   Valid Accuracy: 0.743600
# Epoch 29, CIFAR-10 Batch 2:  Cost: 0.046216   Valid Accuracy: 0.732400
# Epoch 29, CIFAR-10 Batch 3:  Cost: 0.029705   Valid Accuracy: 0.737600
# Epoch 29, CIFAR-10 Batch 4:  Cost: 0.038533   Valid Accuracy: 0.742200
# Epoch 29, CIFAR-10 Batch 5:  Cost: 0.016212   Valid Accuracy: 0.736400
# Epoch 30, CIFAR-10 Batch 1:  Cost: 0.049412   Valid Accuracy: 0.740200
# Epoch 30, CIFAR-10 Batch 2:  Cost: 0.036038   Valid Accuracy: 0.738800
# Epoch 30, CIFAR-10 Batch 3:  Cost: 0.019272   Valid Accuracy: 0.739400
# Epoch 30, CIFAR-10 Batch 4:  Cost: 0.034776   Valid Accuracy: 0.740400
# Epoch 30, CIFAR-10 Batch 5:  Cost: 0.013361   Valid Accuracy: 0.744400
# Epoch 31, CIFAR-10 Batch 1:  Cost: 0.051483   Valid Accuracy: 0.732800
# Epoch 31, CIFAR-10 Batch 2:  Cost: 0.034867   Valid Accuracy: 0.739800
# Epoch 31, CIFAR-10 Batch 3:  Cost: 0.017141   Valid Accuracy: 0.747400
# Epoch 31, CIFAR-10 Batch 4:  Cost: 0.036515   Valid Accuracy: 0.744600
# Epoch 31, CIFAR-10 Batch 5:  Cost: 0.009509   Valid Accuracy: 0.746400
# Epoch 32, CIFAR-10 Batch 1:  Cost: 0.047978   Valid Accuracy: 0.736000
# Epoch 32, CIFAR-10 Batch 2:  Cost: 0.042965   Valid Accuracy: 0.734800
# Epoch 32, CIFAR-10 Batch 3:  Cost: 0.022451   Valid Accuracy: 0.745200
# Epoch 32, CIFAR-10 Batch 4:  Cost: 0.035415   Valid Accuracy: 0.741600
# Epoch 32, CIFAR-10 Batch 5:  Cost: 0.009495   Valid Accuracy: 0.739600
# Epoch 33, CIFAR-10 Batch 1:  Cost: 0.055786   Valid Accuracy: 0.724600
# Epoch 33, CIFAR-10 Batch 2:  Cost: 0.033739   Valid Accuracy: 0.746800
# Epoch 33, CIFAR-10 Batch 3:  Cost: 0.012956   Valid Accuracy: 0.746200
# Epoch 33, CIFAR-10 Batch 4:  Cost: 0.034148   Valid Accuracy: 0.739400
# Epoch 33, CIFAR-10 Batch 5:  Cost: 0.007293   Valid Accuracy: 0.742800
# Epoch 34, CIFAR-10 Batch 1:  Cost: 0.046916   Valid Accuracy: 0.723800
# Epoch 34, CIFAR-10 Batch 2:  Cost: 0.026961   Valid Accuracy: 0.749600
# Epoch 34, CIFAR-10 Batch 3:  Cost: 0.023561   Valid Accuracy: 0.741200
# Epoch 34, CIFAR-10 Batch 4:  Cost: 0.036593   Valid Accuracy: 0.747000
# Epoch 34, CIFAR-10 Batch 5:  Cost: 0.005560   Valid Accuracy: 0.734600
# Epoch 35, CIFAR-10 Batch 1:  Cost: 0.046463   Valid Accuracy: 0.725600
# Epoch 35, CIFAR-10 Batch 2:  Cost: 0.029570   Valid Accuracy: 0.737800
# Epoch 35, CIFAR-10 Batch 3:  Cost: 0.010546   Valid Accuracy: 0.750000
# Epoch 35, CIFAR-10 Batch 4:  Cost: 0.020026   Valid Accuracy: 0.741200
# Epoch 35, CIFAR-10 Batch 5:  Cost: 0.004529   Valid Accuracy: 0.741200
# Epoch 36, CIFAR-10 Batch 1:  Cost: 0.030067   Valid Accuracy: 0.731200
# Epoch 36, CIFAR-10 Batch 2:  Cost: 0.026273   Valid Accuracy: 0.733000
# Epoch 36, CIFAR-10 Batch 3:  Cost: 0.010620   Valid Accuracy: 0.745400
# Epoch 36, CIFAR-10 Batch 4:  Cost: 0.018785   Valid Accuracy: 0.749600
# Epoch 36, CIFAR-10 Batch 5:  Cost: 0.006481   Valid Accuracy: 0.734800
# Epoch 37, CIFAR-10 Batch 1:  Cost: 0.028884   Valid Accuracy: 0.742000
# Epoch 37, CIFAR-10 Batch 2:  Cost: 0.028847   Valid Accuracy: 0.727200
# Epoch 37, CIFAR-10 Batch 3:  Cost: 0.009618   Valid Accuracy: 0.744600
# Epoch 37, CIFAR-10 Batch 4:  Cost: 0.024298   Valid Accuracy: 0.749600
# Epoch 37, CIFAR-10 Batch 5:  Cost: 0.007502   Valid Accuracy: 0.736600
# Epoch 38, CIFAR-10 Batch 1:  Cost: 0.033073   Valid Accuracy: 0.730000
# Epoch 38, CIFAR-10 Batch 2:  Cost: 0.026863   Valid Accuracy: 0.735400
# Epoch 38, CIFAR-10 Batch 3:  Cost: 0.009932   Valid Accuracy: 0.748800
# Epoch 38, CIFAR-10 Batch 4:  Cost: 0.021829   Valid Accuracy: 0.739200
# Epoch 38, CIFAR-10 Batch 5:  Cost: 0.004244   Valid Accuracy: 0.735800
# Epoch 39, CIFAR-10 Batch 1:  Cost: 0.030214   Valid Accuracy: 0.742600
# Epoch 39, CIFAR-10 Batch 2:  Cost: 0.023152   Valid Accuracy: 0.730000
# Epoch 39, CIFAR-10 Batch 3:  Cost: 0.015733   Valid Accuracy: 0.751200
# Epoch 39, CIFAR-10 Batch 4:  Cost: 0.016526   Valid Accuracy: 0.743800
# Epoch 39, CIFAR-10 Batch 5:  Cost: 0.003693   Valid Accuracy: 0.733400
# Epoch 40, CIFAR-10 Batch 1:  Cost: 0.033657   Valid Accuracy: 0.735000
# Epoch 40, CIFAR-10 Batch 2:  Cost: 0.019907   Valid Accuracy: 0.747400
# Epoch 40, CIFAR-10 Batch 3:  Cost: 0.008493   Valid Accuracy: 0.749000
# Epoch 40, CIFAR-10 Batch 4:  Cost: 0.018868   Valid Accuracy: 0.729800
# Epoch 40, CIFAR-10 Batch 5:  Cost: 0.007042   Valid Accuracy: 0.740600
# Epoch 41, CIFAR-10 Batch 1:  Cost: 0.027568   Valid Accuracy: 0.726000
# Epoch 41, CIFAR-10 Batch 2:  Cost: 0.015316   Valid Accuracy: 0.741200
# Epoch 41, CIFAR-10 Batch 3:  Cost: 0.020782   Valid Accuracy: 0.732400
# Epoch 41, CIFAR-10 Batch 4:  Cost: 0.019305   Valid Accuracy: 0.729600
# Epoch 41, CIFAR-10 Batch 5:  Cost: 0.011611   Valid Accuracy: 0.728000
# Epoch 42, CIFAR-10 Batch 1:  Cost: 0.032373   Valid Accuracy: 0.731000
# Epoch 42, CIFAR-10 Batch 2:  Cost: 0.017354   Valid Accuracy: 0.752000
# Epoch 42, CIFAR-10 Batch 3:  Cost: 0.011326   Valid Accuracy: 0.737800
# Epoch 42, CIFAR-10 Batch 4:  Cost: 0.022053   Valid Accuracy: 0.743800
# Epoch 42, CIFAR-10 Batch 5:  Cost: 0.005661   Valid Accuracy: 0.743800
# Epoch 43, CIFAR-10 Batch 1:  Cost: 0.023761   Valid Accuracy: 0.730200
# Epoch 43, CIFAR-10 Batch 2:  Cost: 0.017946   Valid Accuracy: 0.730600
# Epoch 43, CIFAR-10 Batch 3:  Cost: 0.006414   Valid Accuracy: 0.742600
# Epoch 43, CIFAR-10 Batch 4:  Cost: 0.012386   Valid Accuracy: 0.736000
# Epoch 43, CIFAR-10 Batch 5:  Cost: 0.006757   Valid Accuracy: 0.726600
# Epoch 44, CIFAR-10 Batch 1:  Cost: 0.027201   Valid Accuracy: 0.737000
# Epoch 44, CIFAR-10 Batch 2:  Cost: 0.010024   Valid Accuracy: 0.742400
# Epoch 44, CIFAR-10 Batch 3:  Cost: 0.007415   Valid Accuracy: 0.738000
# Epoch 44, CIFAR-10 Batch 4:  Cost: 0.012664   Valid Accuracy: 0.740400
# Epoch 44, CIFAR-10 Batch 5:  Cost: 0.012380   Valid Accuracy: 0.734400
# Epoch 45, CIFAR-10 Batch 1:  Cost: 0.020557   Valid Accuracy: 0.730800
# Epoch 45, CIFAR-10 Batch 2:  Cost: 0.013906   Valid Accuracy: 0.744200
# Epoch 45, CIFAR-10 Batch 3:  Cost: 0.007491   Valid Accuracy: 0.734000
# Epoch 45, CIFAR-10 Batch 4:  Cost: 0.014290   Valid Accuracy: 0.736600
# Epoch 45, CIFAR-10 Batch 5:  Cost: 0.004741   Valid Accuracy: 0.736400
# Epoch 46, CIFAR-10 Batch 1:  Cost: 0.028973   Valid Accuracy: 0.723600
# Epoch 46, CIFAR-10 Batch 2:  Cost: 0.019052   Valid Accuracy: 0.733000
# Epoch 46, CIFAR-10 Batch 3:  Cost: 0.009907   Valid Accuracy: 0.746000
# Epoch 46, CIFAR-10 Batch 4:  Cost: 0.011912   Valid Accuracy: 0.733200
# Epoch 46, CIFAR-10 Batch 5:  Cost: 0.005728   Valid Accuracy: 0.739400
# Epoch 47, CIFAR-10 Batch 1:  Cost: 0.014184   Valid Accuracy: 0.741200
# Epoch 47, CIFAR-10 Batch 2:  Cost: 0.015651   Valid Accuracy: 0.726400
# Epoch 47, CIFAR-10 Batch 3:  Cost: 0.007267   Valid Accuracy: 0.738000
# Epoch 47, CIFAR-10 Batch 4:  Cost: 0.008982   Valid Accuracy: 0.729800
# Epoch 47, CIFAR-10 Batch 5:  Cost: 0.003732   Valid Accuracy: 0.736800
# Epoch 48, CIFAR-10 Batch 1:  Cost: 0.022705   Valid Accuracy: 0.739400
# Epoch 48, CIFAR-10 Batch 2:  Cost: 0.007362   Valid Accuracy: 0.738400
# Epoch 48, CIFAR-10 Batch 3:  Cost: 0.007453   Valid Accuracy: 0.745000
# Epoch 48, CIFAR-10 Batch 4:  Cost: 0.007301   Valid Accuracy: 0.743200
# Epoch 48, CIFAR-10 Batch 5:  Cost: 0.002576   Valid Accuracy: 0.738800
# Epoch 49, CIFAR-10 Batch 1:  Cost: 0.012588   Valid Accuracy: 0.750200
# Epoch 49, CIFAR-10 Batch 2:  Cost: 0.009966   Valid Accuracy: 0.733800
# Epoch 49, CIFAR-10 Batch 3:  Cost: 0.010333   Valid Accuracy: 0.732800
# Epoch 49, CIFAR-10 Batch 4:  Cost: 0.012140   Valid Accuracy: 0.745400
# Epoch 49, CIFAR-10 Batch 5:  Cost: 0.003972   Valid Accuracy: 0.736400
# Epoch 50, CIFAR-10 Batch 1:  Cost: 0.013645   Valid Accuracy: 0.748800
# Epoch 50, CIFAR-10 Batch 2:  Cost: 0.005226   Valid Accuracy: 0.744800
# Epoch 50, CIFAR-10 Batch 3:  Cost: 0.003639   Valid Accuracy: 0.747800
# Epoch 50, CIFAR-10 Batch 4:  Cost: 0.009178   Valid Accuracy: 0.737400
# Epoch 50, CIFAR-10 Batch 5:  Cost: 0.003153   Valid Accuracy: 0.745400
# Epoch 51, CIFAR-10 Batch 1:  Cost: 0.017788   Valid Accuracy: 0.748000
# Epoch 51, CIFAR-10 Batch 2:  Cost: 0.008179   Valid Accuracy: 0.735000
# Epoch 51, CIFAR-10 Batch 3:  Cost: 0.002822   Valid Accuracy: 0.744400
# Epoch 51, CIFAR-10 Batch 4:  Cost: 0.007720   Valid Accuracy: 0.733400
# Epoch 51, CIFAR-10 Batch 5:  Cost: 0.002072   Valid Accuracy: 0.743800
# Epoch 52, CIFAR-10 Batch 1:  Cost: 0.016244   Valid Accuracy: 0.741200
# Epoch 52, CIFAR-10 Batch 2:  Cost: 0.013494   Valid Accuracy: 0.734000
# Epoch 52, CIFAR-10 Batch 3:  Cost: 0.003370   Valid Accuracy: 0.733600
# Epoch 52, CIFAR-10 Batch 4:  Cost: 0.006183   Valid Accuracy: 0.735600
# Epoch 52, CIFAR-10 Batch 5:  Cost: 0.002119   Valid Accuracy: 0.730200
# Epoch 53, CIFAR-10 Batch 1:  Cost: 0.011004   Valid Accuracy: 0.742400
# Epoch 53, CIFAR-10 Batch 2:  Cost: 0.003842   Valid Accuracy: 0.740200
# Epoch 53, CIFAR-10 Batch 3:  Cost: 0.001806   Valid Accuracy: 0.737200
# Epoch 53, CIFAR-10 Batch 4:  Cost: 0.007158   Valid Accuracy: 0.729000
# Epoch 53, CIFAR-10 Batch 5:  Cost: 0.001238   Valid Accuracy: 0.746200
# Epoch 54, CIFAR-10 Batch 1:  Cost: 0.011768   Valid Accuracy: 0.746600
# Epoch 54, CIFAR-10 Batch 2:  Cost: 0.002477   Valid Accuracy: 0.743000
# Epoch 54, CIFAR-10 Batch 3:  Cost: 0.005039   Valid Accuracy: 0.739800
# Epoch 54, CIFAR-10 Batch 4:  Cost: 0.003890   Valid Accuracy: 0.738600
# Epoch 54, CIFAR-10 Batch 5:  Cost: 0.002792   Valid Accuracy: 0.744000
# Epoch 55, CIFAR-10 Batch 1:  Cost: 0.013732   Valid Accuracy: 0.742000
# Epoch 55, CIFAR-10 Batch 2:  Cost: 0.007503   Valid Accuracy: 0.746200
# Epoch 55, CIFAR-10 Batch 3:  Cost: 0.005308   Valid Accuracy: 0.739000
# Epoch 55, CIFAR-10 Batch 4:  Cost: 0.008219   Valid Accuracy: 0.731800
# Epoch 55, CIFAR-10 Batch 5:  Cost: 0.002597   Valid Accuracy: 0.732200
# Epoch 56, CIFAR-10 Batch 1:  Cost: 0.011332   Valid Accuracy: 0.752800
# Epoch 56, CIFAR-10 Batch 2:  Cost: 0.002392   Valid Accuracy: 0.748800
# Epoch 56, CIFAR-10 Batch 3:  Cost: 0.001823   Valid Accuracy: 0.741600
# Epoch 56, CIFAR-10 Batch 4:  Cost: 0.006517   Valid Accuracy: 0.743400
# Epoch 56, CIFAR-10 Batch 5:  Cost: 0.006516   Valid Accuracy: 0.737400
# Epoch 57, CIFAR-10 Batch 1:  Cost: 0.008213   Valid Accuracy: 0.746000
# Epoch 57, CIFAR-10 Batch 2:  Cost: 0.003802   Valid Accuracy: 0.746000
# Epoch 57, CIFAR-10 Batch 3:  Cost: 0.005272   Valid Accuracy: 0.740200
# Epoch 57, CIFAR-10 Batch 4:  Cost: 0.008776   Valid Accuracy: 0.738800
# Epoch 57, CIFAR-10 Batch 5:  Cost: 0.004051   Valid Accuracy: 0.743400
# Epoch 58, CIFAR-10 Batch 1:  Cost: 0.013257   Valid Accuracy: 0.740600
# Epoch 58, CIFAR-10 Batch 2:  Cost: 0.009984   Valid Accuracy: 0.739800
# Epoch 58, CIFAR-10 Batch 3:  Cost: 0.001149   Valid Accuracy: 0.746400
# Epoch 58, CIFAR-10 Batch 4:  Cost: 0.005268   Valid Accuracy: 0.742800
# Epoch 58, CIFAR-10 Batch 5:  Cost: 0.000635   Valid Accuracy: 0.740800
# Epoch 59, CIFAR-10 Batch 1:  Cost: 0.012820   Valid Accuracy: 0.744000
# Epoch 59, CIFAR-10 Batch 2:  Cost: 0.004645   Valid Accuracy: 0.745800
# Epoch 59, CIFAR-10 Batch 3:  Cost: 0.001795   Valid Accuracy: 0.733000
# Epoch 59, CIFAR-10 Batch 4:  Cost: 0.004498   Valid Accuracy: 0.736400
# Epoch 59, CIFAR-10 Batch 5:  Cost: 0.003938   Valid Accuracy: 0.738400
# Epoch 60, CIFAR-10 Batch 1:  Cost: 0.005793   Valid Accuracy: 0.738800
# Epoch 60, CIFAR-10 Batch 2:  Cost: 0.004532   Valid Accuracy: 0.731600
# Epoch 60, CIFAR-10 Batch 3:  Cost: 0.003063   Valid Accuracy: 0.732200
# Epoch 60, CIFAR-10 Batch 4:  Cost: 0.004940   Valid Accuracy: 0.737800
# Epoch 60, CIFAR-10 Batch 5:  Cost: 0.001085   Valid Accuracy: 0.753000
# Epoch 61, CIFAR-10 Batch 1:  Cost: 0.006600   Valid Accuracy: 0.740800
# Epoch 61, CIFAR-10 Batch 2:  Cost: 0.005385   Valid Accuracy: 0.741600
# Epoch 61, CIFAR-10 Batch 3:  Cost: 0.001708   Valid Accuracy: 0.741800
# Epoch 61, CIFAR-10 Batch 4:  Cost: 0.004265   Valid Accuracy: 0.733800
# Epoch 61, CIFAR-10 Batch 5:  Cost: 0.004847   Valid Accuracy: 0.739600
# Epoch 62, CIFAR-10 Batch 1:  Cost: 0.006785   Valid Accuracy: 0.748800
# Epoch 62, CIFAR-10 Batch 2:  Cost: 0.003411   Valid Accuracy: 0.737400
# Epoch 62, CIFAR-10 Batch 3:  Cost: 0.002740   Valid Accuracy: 0.745200
# Epoch 62, CIFAR-10 Batch 4:  Cost: 0.001751   Valid Accuracy: 0.741600
# Epoch 62, CIFAR-10 Batch 5:  Cost: 0.001378   Valid Accuracy: 0.735600
# Epoch 63, CIFAR-10 Batch 1:  Cost: 0.003882   Valid Accuracy: 0.744400
# Epoch 63, CIFAR-10 Batch 2:  Cost: 0.003901   Valid Accuracy: 0.740800
# Epoch 63, CIFAR-10 Batch 3:  Cost: 0.003436   Valid Accuracy: 0.739800
# Epoch 63, CIFAR-10 Batch 4:  Cost: 0.010494   Valid Accuracy: 0.742600
# Epoch 63, CIFAR-10 Batch 5:  Cost: 0.001862   Valid Accuracy: 0.741000
# Epoch 64, CIFAR-10 Batch 1:  Cost: 0.004987   Valid Accuracy: 0.744000
# Epoch 64, CIFAR-10 Batch 2:  Cost: 0.005147   Valid Accuracy: 0.740800
# Epoch 64, CIFAR-10 Batch 3:  Cost: 0.003436   Valid Accuracy: 0.737000
# Epoch 64, CIFAR-10 Batch 4:  Cost: 0.007783   Valid Accuracy: 0.741600
# Epoch 64, CIFAR-10 Batch 5:  Cost: 0.000573   Valid Accuracy: 0.746000
# Epoch 65, CIFAR-10 Batch 1:  Cost: 0.005527   Valid Accuracy: 0.745800
# Epoch 65, CIFAR-10 Batch 2:  Cost: 0.007112   Valid Accuracy: 0.734000
# Epoch 65, CIFAR-10 Batch 3:  Cost: 0.001205   Valid Accuracy: 0.735400
# Epoch 65, CIFAR-10 Batch 4:  Cost: 0.011360   Valid Accuracy: 0.736200
# Epoch 65, CIFAR-10 Batch 5:  Cost: 0.003867   Valid Accuracy: 0.750400
# Epoch 66, CIFAR-10 Batch 1:  Cost: 0.004058   Valid Accuracy: 0.749000
# Epoch 66, CIFAR-10 Batch 2:  Cost: 0.000961   Valid Accuracy: 0.738200
# Epoch 66, CIFAR-10 Batch 3:  Cost: 0.001129   Valid Accuracy: 0.742800
# Epoch 66, CIFAR-10 Batch 4:  Cost: 0.005461   Valid Accuracy: 0.747400
# Epoch 66, CIFAR-10 Batch 5:  Cost: 0.001831   Valid Accuracy: 0.746400
# Epoch 67, CIFAR-10 Batch 1:  Cost: 0.004775   Valid Accuracy: 0.745800
# Epoch 67, CIFAR-10 Batch 2:  Cost: 0.002782   Valid Accuracy: 0.746400
# Epoch 67, CIFAR-10 Batch 3:  Cost: 0.000728   Valid Accuracy: 0.744000
# Epoch 67, CIFAR-10 Batch 4:  Cost: 0.007898   Valid Accuracy: 0.726400
# Epoch 67, CIFAR-10 Batch 5:  Cost: 0.000320   Valid Accuracy: 0.748200
# Epoch 68, CIFAR-10 Batch 1:  Cost: 0.008299   Valid Accuracy: 0.749000
# Epoch 68, CIFAR-10 Batch 2:  Cost: 0.002011   Valid Accuracy: 0.749800
# Epoch 68, CIFAR-10 Batch 3:  Cost: 0.002875   Valid Accuracy: 0.738600
# Epoch 68, CIFAR-10 Batch 4:  Cost: 0.001630   Valid Accuracy: 0.740400
# Epoch 68, CIFAR-10 Batch 5:  Cost: 0.001854   Valid Accuracy: 0.738200
# Epoch 69, CIFAR-10 Batch 1:  Cost: 0.003381   Valid Accuracy: 0.745800
# Epoch 69, CIFAR-10 Batch 2:  Cost: 0.001633   Valid Accuracy: 0.739800
# Epoch 69, CIFAR-10 Batch 3:  Cost: 0.000893   Valid Accuracy: 0.742200
# Epoch 69, CIFAR-10 Batch 4:  Cost: 0.008626   Valid Accuracy: 0.728800
# Epoch 69, CIFAR-10 Batch 5:  Cost: 0.000431   Valid Accuracy: 0.747600
# Epoch 70, CIFAR-10 Batch 1:  Cost: 0.005590   Valid Accuracy: 0.745000
# Epoch 70, CIFAR-10 Batch 2:  Cost: 0.000817   Valid Accuracy: 0.739000
# Epoch 70, CIFAR-10 Batch 3:  Cost: 0.010967   Valid Accuracy: 0.740800
# Epoch 70, CIFAR-10 Batch 4:  Cost: 0.004650   Valid Accuracy: 0.748400
# Epoch 70, CIFAR-10 Batch 5:  Cost: 0.000553   Valid Accuracy: 0.740600
# Epoch 71, CIFAR-10 Batch 1:  Cost: 0.004731   Valid Accuracy: 0.746600
# Epoch 71, CIFAR-10 Batch 2:  Cost: 0.001373   Valid Accuracy: 0.747800
# Epoch 71, CIFAR-10 Batch 3:  Cost: 0.003016   Valid Accuracy: 0.742600
# Epoch 71, CIFAR-10 Batch 4:  Cost: 0.001762   Valid Accuracy: 0.741800
# Epoch 71, CIFAR-10 Batch 5:  Cost: 0.001147   Valid Accuracy: 0.748800
# Epoch 72, CIFAR-10 Batch 1:  Cost: 0.005307   Valid Accuracy: 0.747600
# Epoch 72, CIFAR-10 Batch 2:  Cost: 0.000999   Valid Accuracy: 0.748400
# Epoch 72, CIFAR-10 Batch 3:  Cost: 0.000977   Valid Accuracy: 0.740000
# Epoch 72, CIFAR-10 Batch 4:  Cost: 0.000846   Valid Accuracy: 0.744000
# Epoch 72, CIFAR-10 Batch 5:  Cost: 0.001694   Valid Accuracy: 0.738200
# Epoch 73, CIFAR-10 Batch 1:  Cost: 0.002918   Valid Accuracy: 0.741800
# Epoch 73, CIFAR-10 Batch 2:  Cost: 0.001079   Valid Accuracy: 0.743400
# Epoch 73, CIFAR-10 Batch 3:  Cost: 0.000690   Valid Accuracy: 0.741600
# Epoch 73, CIFAR-10 Batch 4:  Cost: 0.006029   Valid Accuracy: 0.738200
# Epoch 73, CIFAR-10 Batch 5:  Cost: 0.000607   Valid Accuracy: 0.744800
# Epoch 74, CIFAR-10 Batch 1:  Cost: 0.010832   Valid Accuracy: 0.741000
# Epoch 74, CIFAR-10 Batch 2:  Cost: 0.002399   Valid Accuracy: 0.742600
# Epoch 74, CIFAR-10 Batch 3:  Cost: 0.002435   Valid Accuracy: 0.739600
# Epoch 74, CIFAR-10 Batch 4:  Cost: 0.003074   Valid Accuracy: 0.743800
# Epoch 74, CIFAR-10 Batch 5:  Cost: 0.000300   Valid Accuracy: 0.742200
# Epoch 75, CIFAR-10 Batch 1:  Cost: 0.002503   Valid Accuracy: 0.744200
# Epoch 75, CIFAR-10 Batch 2:  Cost: 0.001420   Valid Accuracy: 0.733400
# Epoch 75, CIFAR-10 Batch 3:  Cost: 0.001249   Valid Accuracy: 0.745000
# Epoch 75, CIFAR-10 Batch 4:  Cost: 0.006282   Valid Accuracy: 0.741000
# Epoch 75, CIFAR-10 Batch 5:  Cost: 0.000636   Valid Accuracy: 0.742000
# Epoch 76, CIFAR-10 Batch 1:  Cost: 0.001412   Valid Accuracy: 0.746600
# Epoch 76, CIFAR-10 Batch 2:  Cost: 0.001127   Valid Accuracy: 0.747200
# Epoch 76, CIFAR-10 Batch 3:  Cost: 0.003409   Valid Accuracy: 0.748600
# Epoch 76, CIFAR-10 Batch 4:  Cost: 0.002907   Valid Accuracy: 0.738400
# Epoch 76, CIFAR-10 Batch 5:  Cost: 0.000921   Valid Accuracy: 0.748000
# Epoch 77, CIFAR-10 Batch 1:  Cost: 0.001325   Valid Accuracy: 0.748600
# Epoch 77, CIFAR-10 Batch 2:  Cost: 0.000508   Valid Accuracy: 0.746400
# Epoch 77, CIFAR-10 Batch 3:  Cost: 0.001210   Valid Accuracy: 0.739400
# Epoch 77, CIFAR-10 Batch 4:  Cost: 0.004284   Valid Accuracy: 0.739800
# Epoch 77, CIFAR-10 Batch 5:  Cost: 0.000381   Valid Accuracy: 0.745600
# Epoch 78, CIFAR-10 Batch 1:  Cost: 0.001897   Valid Accuracy: 0.746400
# Epoch 78, CIFAR-10 Batch 2:  Cost: 0.001800   Valid Accuracy: 0.742400
# Epoch 78, CIFAR-10 Batch 3:  Cost: 0.000678   Valid Accuracy: 0.747800
# Epoch 78, CIFAR-10 Batch 4:  Cost: 0.001000   Valid Accuracy: 0.746400
# Epoch 78, CIFAR-10 Batch 5:  Cost: 0.000709   Valid Accuracy: 0.742200
# Epoch 79, CIFAR-10 Batch 1:  Cost: 0.001527   Valid Accuracy: 0.756200
# Epoch 79, CIFAR-10 Batch 2:  Cost: 0.003025   Valid Accuracy: 0.745200
# Epoch 79, CIFAR-10 Batch 3:  Cost: 0.001164   Valid Accuracy: 0.747000
# Epoch 79, CIFAR-10 Batch 4:  Cost: 0.001882   Valid Accuracy: 0.740000
# Epoch 79, CIFAR-10 Batch 5:  Cost: 0.000397   Valid Accuracy: 0.737000
# Epoch 80, CIFAR-10 Batch 1:  Cost: 0.001358   Valid Accuracy: 0.749200
# Epoch 80, CIFAR-10 Batch 2:  Cost: 0.001073   Valid Accuracy: 0.750800
# Epoch 80, CIFAR-10 Batch 3:  Cost: 0.002132   Valid Accuracy: 0.747200
# Epoch 80, CIFAR-10 Batch 4:  Cost: 0.000688   Valid Accuracy: 0.743600
# Epoch 80, CIFAR-10 Batch 5:  Cost: 0.000654   Valid Accuracy: 0.749400
# Epoch 81, CIFAR-10 Batch 1:  Cost: 0.001813   Valid Accuracy: 0.740400
# Epoch 81, CIFAR-10 Batch 2:  Cost: 0.001301   Valid Accuracy: 0.744400
# Epoch 81, CIFAR-10 Batch 3:  Cost: 0.001191   Valid Accuracy: 0.748000
# Epoch 81, CIFAR-10 Batch 4:  Cost: 0.000779   Valid Accuracy: 0.748400
# Epoch 81, CIFAR-10 Batch 5:  Cost: 0.000377   Valid Accuracy: 0.741400
# Epoch 82, CIFAR-10 Batch 1:  Cost: 0.003506   Valid Accuracy: 0.742200
# Epoch 82, CIFAR-10 Batch 2:  Cost: 0.000367   Valid Accuracy: 0.745600
# Epoch 82, CIFAR-10 Batch 3:  Cost: 0.001943   Valid Accuracy: 0.747400
# Epoch 82, CIFAR-10 Batch 4:  Cost: 0.007186   Valid Accuracy: 0.746000
# Epoch 82, CIFAR-10 Batch 5:  Cost: 0.000648   Valid Accuracy: 0.745000
# Epoch 83, CIFAR-10 Batch 1:  Cost: 0.001328   Valid Accuracy: 0.744600
# Epoch 83, CIFAR-10 Batch 2:  Cost: 0.000465   Valid Accuracy: 0.742600
# Epoch 83, CIFAR-10 Batch 3:  Cost: 0.007767   Valid Accuracy: 0.745200
# Epoch 83, CIFAR-10 Batch 4:  Cost: 0.000909   Valid Accuracy: 0.747200
# Epoch 83, CIFAR-10 Batch 5:  Cost: 0.001748   Valid Accuracy: 0.731400
# Epoch 84, CIFAR-10 Batch 1:  Cost: 0.003647   Valid Accuracy: 0.747800
# Epoch 84, CIFAR-10 Batch 2:  Cost: 0.001971   Valid Accuracy: 0.738600
# Epoch 84, CIFAR-10 Batch 3:  Cost: 0.009406   Valid Accuracy: 0.750600
# Epoch 84, CIFAR-10 Batch 4:  Cost: 0.001395   Valid Accuracy: 0.746000
# Epoch 84, CIFAR-10 Batch 5:  Cost: 0.000340   Valid Accuracy: 0.749800
# Epoch 85, CIFAR-10 Batch 1:  Cost: 0.001774   Valid Accuracy: 0.747800
# Epoch 85, CIFAR-10 Batch 2:  Cost: 0.000701   Valid Accuracy: 0.746800
# Epoch 85, CIFAR-10 Batch 3:  Cost: 0.002052   Valid Accuracy: 0.748400
# Epoch 85, CIFAR-10 Batch 4:  Cost: 0.003235   Valid Accuracy: 0.741200
# Epoch 85, CIFAR-10 Batch 5:  Cost: 0.000844   Valid Accuracy: 0.740800
# Epoch 86, CIFAR-10 Batch 1:  Cost: 0.006988   Valid Accuracy: 0.737200
# Epoch 86, CIFAR-10 Batch 2:  Cost: 0.002119   Valid Accuracy: 0.749000
# Epoch 86, CIFAR-10 Batch 3:  Cost: 0.002450   Valid Accuracy: 0.751600
# Epoch 86, CIFAR-10 Batch 4:  Cost: 0.000896   Valid Accuracy: 0.747000
# Epoch 86, CIFAR-10 Batch 5:  Cost: 0.002288   Valid Accuracy: 0.744000
# Epoch 87, CIFAR-10 Batch 1:  Cost: 0.003310   Valid Accuracy: 0.744600
# Epoch 87, CIFAR-10 Batch 2:  Cost: 0.000562   Valid Accuracy: 0.747600
# Epoch 87, CIFAR-10 Batch 3:  Cost: 0.007944   Valid Accuracy: 0.752200
# Epoch 87, CIFAR-10 Batch 4:  Cost: 0.002168   Valid Accuracy: 0.749600
# Epoch 87, CIFAR-10 Batch 5:  Cost: 0.000464   Valid Accuracy: 0.743200
# Epoch 88, CIFAR-10 Batch 1:  Cost: 0.005667   Valid Accuracy: 0.734000
# Epoch 88, CIFAR-10 Batch 2:  Cost: 0.000563   Valid Accuracy: 0.744800
# Epoch 88, CIFAR-10 Batch 3:  Cost: 0.000464   Valid Accuracy: 0.751400
# Epoch 88, CIFAR-10 Batch 4:  Cost: 0.001331   Valid Accuracy: 0.743000
# Epoch 88, CIFAR-10 Batch 5:  Cost: 0.000272   Valid Accuracy: 0.745400
# Epoch 89, CIFAR-10 Batch 1:  Cost: 0.002991   Valid Accuracy: 0.743200
# Epoch 89, CIFAR-10 Batch 2:  Cost: 0.000189   Valid Accuracy: 0.752800
# Epoch 89, CIFAR-10 Batch 3:  Cost: 0.000301   Valid Accuracy: 0.746400
# Epoch 89, CIFAR-10 Batch 4:  Cost: 0.000693   Valid Accuracy: 0.748000
# Epoch 89, CIFAR-10 Batch 5:  Cost: 0.000673   Valid Accuracy: 0.742200
# Epoch 90, CIFAR-10 Batch 1:  Cost: 0.004921   Valid Accuracy: 0.750000
# Epoch 90, CIFAR-10 Batch 2:  Cost: 0.000481   Valid Accuracy: 0.753200
# Epoch 90, CIFAR-10 Batch 3:  Cost: 0.004504   Valid Accuracy: 0.740000
# Epoch 90, CIFAR-10 Batch 4:  Cost: 0.000628   Valid Accuracy: 0.745800
# Epoch 90, CIFAR-10 Batch 5:  Cost: 0.000158   Valid Accuracy: 0.746000
# Epoch 91, CIFAR-10 Batch 1:  Cost: 0.001506   Valid Accuracy: 0.744200
# Epoch 91, CIFAR-10 Batch 2:  Cost: 0.003923   Valid Accuracy: 0.740800
# Epoch 91, CIFAR-10 Batch 3:  Cost: 0.001332   Valid Accuracy: 0.750400
# Epoch 91, CIFAR-10 Batch 4:  Cost: 0.000140   Valid Accuracy: 0.750600
# Epoch 91, CIFAR-10 Batch 5:  Cost: 0.001378   Valid Accuracy: 0.747000
# Epoch 92, CIFAR-10 Batch 1:  Cost: 0.004754   Valid Accuracy: 0.741000
# Epoch 92, CIFAR-10 Batch 2:  Cost: 0.000346   Valid Accuracy: 0.746600
# Epoch 92, CIFAR-10 Batch 3:  Cost: 0.000491   Valid Accuracy: 0.748400
# Epoch 92, CIFAR-10 Batch 4:  Cost: 0.000485   Valid Accuracy: 0.743600
# Epoch 92, CIFAR-10 Batch 5:  Cost: 0.000678   Valid Accuracy: 0.745200
# Epoch 93, CIFAR-10 Batch 1:  Cost: 0.001100   Valid Accuracy: 0.746400
# Epoch 93, CIFAR-10 Batch 2:  Cost: 0.002054   Valid Accuracy: 0.746600
# Epoch 93, CIFAR-10 Batch 3:  Cost: 0.000908   Valid Accuracy: 0.750600
# Epoch 93, CIFAR-10 Batch 4:  Cost: 0.000515   Valid Accuracy: 0.754000
# Epoch 93, CIFAR-10 Batch 5:  Cost: 0.000565   Valid Accuracy: 0.758200
# Epoch 94, CIFAR-10 Batch 1:  Cost: 0.003107   Valid Accuracy: 0.744400
# Epoch 94, CIFAR-10 Batch 2:  Cost: 0.001100   Valid Accuracy: 0.754600
# Epoch 94, CIFAR-10 Batch 3:  Cost: 0.001781   Valid Accuracy: 0.749400
# Epoch 94, CIFAR-10 Batch 4:  Cost: 0.003062   Valid Accuracy: 0.749000
# Epoch 94, CIFAR-10 Batch 5:  Cost: 0.000395   Valid Accuracy: 0.746400
# Epoch 95, CIFAR-10 Batch 1:  Cost: 0.001271   Valid Accuracy: 0.746200
# Epoch 95, CIFAR-10 Batch 2:  Cost: 0.003367   Valid Accuracy: 0.738200
# Epoch 95, CIFAR-10 Batch 3:  Cost: 0.000526   Valid Accuracy: 0.746400
# Epoch 95, CIFAR-10 Batch 4:  Cost: 0.001186   Valid Accuracy: 0.749800
# Epoch 95, CIFAR-10 Batch 5:  Cost: 0.000557   Valid Accuracy: 0.748000
# Epoch 96, CIFAR-10 Batch 1:  Cost: 0.001675   Valid Accuracy: 0.746400
# Epoch 96, CIFAR-10 Batch 2:  Cost: 0.001172   Valid Accuracy: 0.744800
# Epoch 96, CIFAR-10 Batch 3:  Cost: 0.000849   Valid Accuracy: 0.750400
# Epoch 96, CIFAR-10 Batch 4:  Cost: 0.000879   Valid Accuracy: 0.753200
# Epoch 96, CIFAR-10 Batch 5:  Cost: 0.000390   Valid Accuracy: 0.746200
# Epoch 97, CIFAR-10 Batch 1:  Cost: 0.001283   Valid Accuracy: 0.739600
# Epoch 97, CIFAR-10 Batch 2:  Cost: 0.000195   Valid Accuracy: 0.749600
# Epoch 97, CIFAR-10 Batch 3:  Cost: 0.002271   Valid Accuracy: 0.743800
# Epoch 97, CIFAR-10 Batch 4:  Cost: 0.001438   Valid Accuracy: 0.746800
# Epoch 97, CIFAR-10 Batch 5:  Cost: 0.000196   Valid Accuracy: 0.752000
# Epoch 98, CIFAR-10 Batch 1:  Cost: 0.001476   Valid Accuracy: 0.758200
# Epoch 98, CIFAR-10 Batch 2:  Cost: 0.000332   Valid Accuracy: 0.751000
# Epoch 98, CIFAR-10 Batch 3:  Cost: 0.000473   Valid Accuracy: 0.751600
# Epoch 98, CIFAR-10 Batch 4:  Cost: 0.002604   Valid Accuracy: 0.750200
# Epoch 98, CIFAR-10 Batch 5:  Cost: 0.000396   Valid Accuracy: 0.746400
# Epoch 99, CIFAR-10 Batch 1:  Cost: 0.001413   Valid Accuracy: 0.741200
# Epoch 99, CIFAR-10 Batch 2:  Cost: 0.000377   Valid Accuracy: 0.747800
# Epoch 99, CIFAR-10 Batch 3:  Cost: 0.000618   Valid Accuracy: 0.748000
# Epoch 99, CIFAR-10 Batch 4:  Cost: 0.001730   Valid Accuracy: 0.748200
# Epoch 99, CIFAR-10 Batch 5:  Cost: 0.004295   Valid Accuracy: 0.752000
# Epoch 100, CIFAR-10 Batch 1:  Cost: 0.001393   Valid Accuracy: 0.746200
# Epoch 100, CIFAR-10 Batch 2:  Cost: 0.000530   Valid Accuracy: 0.751600
# Epoch 100, CIFAR-10 Batch 3:  Cost: 0.000147   Valid Accuracy: 0.750400
# Epoch 100, CIFAR-10 Batch 4:  Cost: 0.000432   Valid Accuracy: 0.751200
# Epoch 100, CIFAR-10 Batch 5:  Cost: 0.001967   Valid Accuracy: 0.749400

# %% [markdown]
# # 检查点
#
# 模型已保存到本地。
#
# ## 测试模型
#
# 利用测试数据集测试你的模型。这将是最终的准确率。你的准确率应该高于 50%。如果没达到，请继续调整模型结构和参数。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.7341772151898734

# %% [markdown]
# ## 为何准确率只有50-80%？
#
# 你可能想问，为何准确率不能更高了？首先，对于简单的 CNN 网络来说，50% 已经不低了。纯粹猜测的准确率为10%。但是，你可能注意到有人的准确率[远远超过 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130)。这是因为我们还没有介绍所有的神经网络知识。我们还需要掌握一些其他技巧。
#
# ## 提交项目
#
# 提交项目时，确保先运行所有单元，然后再保存记事本。将 notebook 文件另存为“dlnd_image_classification.ipynb”，再在目录 "File" -> "Download as" 另存为 HTML 格式。请在提交的项目中包含 “helper.py” 和 “problem_unittests.py” 文件。
